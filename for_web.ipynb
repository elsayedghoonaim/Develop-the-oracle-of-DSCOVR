# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


import tensorflow as tf
from keras.models import load_model
from keras.models import save_model
from keras.metrics import MeanSquaredError, MeanAbsoluteError
from keras.layers import Dense, Dropout
from keras import Sequential
from keras.regularizers import L1,L2
from keras.optimizers import Adam
from keras.metrics import MeanSquaredError, MeanAbsoluteError

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv(r'C:\Users\elsayed\Projects\AI\NASA space apps\Solar Wind\_data\omni_csvs\DatedFullData.csv')

# %%
df.set_index(['Datetime'] , inplace = True)
df.drop(columns=['Unnamed: 0'] , inplace = True)

# %%
df.head()
# Out:
#                             Epoch  Rot#  IMF  PLS  IMF_PTS  PLS_PTS  ABS_B  \
# Datetime
# 2011-01-01 00:00:00  6.346106e+13  2421   51   52       62       38    4.6
# 2011-01-01 01:00:00  6.346106e+13  2421   51   52       56       34    4.5
# 2011-01-01 02:00:00  6.346107e+13  2421   51   52       56       32    4.6
# 2011-01-01 03:00:00  6.346107e+13  2421   51   52       63       38    3.3
# 2011-01-01 04:00:00  6.346107e+13  2421   51   52       60       37    3.2
#
#                        F  THETA_AV  PHI_AV  ...  F10_INDEX  KP  DST  AE  \
# Datetime                                    ...
# 2011-01-01 00:00:00  4.3     -26.4   127.7  ...      999.9  13  -11  39
# 2011-01-01 01:00:00  3.4       5.1   115.2  ...      999.9  13  -11  61
# 2011-01-01 02:00:00  4.1       4.2   123.9  ...      999.9  13   -9  35
# 2011-01-01 03:00:00  1.8      13.9   122.8  ...      999.9   7   -5  42
# 2011-01-01 04:00:00  2.9     -26.1   124.2  ...      999.9   7   -3  37
#
#                      AP_INDEX  AL_INDEX  AU_INDEX  PC_N_INDEX  \
# Datetime
# 2011-01-01 00:00:00         5       -12        27         0.2
# 2011-01-01 01:00:00         5       -29        32         0.7
# 2011-01-01 02:00:00         5       -15        20         0.3
# 2011-01-01 03:00:00         3        -9        33         0.6
# 2011-01-01 04:00:00         3        -7        30         0.3
#
#                      Solar_Lyman_alpha  Proton_QI
# Datetime
# 2011-01-01 00:00:00           0.006706     0.0243
# 2011-01-01 01:00:00           0.006706     0.0195
# 2011-01-01 02:00:00           0.006706     0.0231
# 2011-01-01 03:00:00           0.006706     0.0076
# 2011-01-01 04:00:00           0.006706     0.0059
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111445 entries, 2011-01-01 00:00:00 to 2023-09-18 12:00:00
# Data columns (total 55 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Epoch              111445 non-null  float64
#  1   Rot#               111445 non-null  int64
#  2   IMF                111445 non-null  int64
#  3   PLS                111445 non-null  int64
#  4   IMF_PTS            111445 non-null  int64
#  5   PLS_PTS            111445 non-null  int64
#  6   ABS_B              111445 non-null  float64
#  7   F                  111445 non-null  float64
#  8   THETA_AV           111445 non-null  float64
#  9   PHI_AV             111445 non-null  float64
#  10  BX_GSE             111445 non-null  float64
#  11  BY_GSE             111445 non-null  float64
#  12  BZ_GSE             111445 non-null  float64
#  13  BY_GSM             111445 non-null  float64
#  14  BZ_GSM             111445 non-null  float64
#  15  SIGMA-ABS_B        111445 non-null  float64
#  16  SIGMA-B            111445 non-null  float64
#  17  SIGMA-Bx           111445 non-null  float64
#  18  SIGMA-By           111445 non-null  float64
#  19  SIGMA-Bz           111445 non-null  float64
#  20  T                  111445 non-null  float64
#  21  N                  111445 non-null  float64
#  22  V                  111445 non-null  float64
#  23  PHI-V              111445 non-null  float64
#  24  THETA-V            111445 non-null  float64
#  25  Ratio              111445 non-null  float64
#  26  Pressure           111445 non-null  float64
#  27  SIGMA-T            111445 non-null  float64
#  28  SIGMA-N            111445 non-null  float64
#  29  SIGMA-V            111445 non-null  float64
#  30  SIGMA-PHI-V        111445 non-null  float64
#  31  SIGMA-THETA-V      111445 non-null  float64
#  32  SIGMA-ratio        111445 non-null  float64
#  33  E                  111445 non-null  float64
#  34  Beta               111445 non-null  float64
#  35  Mach_num           111445 non-null  float64
#  36  Mgs_mach_num       111445 non-null  float64
#  37  PR-FLX_1           111445 non-null  float64
#  38  PR-FLX_2           111445 non-null  float64
#  39  PR-FLX_4           111445 non-null  float64
#  40  PR-FLX_10          111445 non-null  float64
#  41  PR-FLX_30          111445 non-null  float64
#  42  PR-FLX_60          111445 non-null  float64
#  43  MFLX               111445 non-null  int64
#  44  R                  111445 non-null  int64
#  45  F10_INDEX          111445 non-null  float64
#  46  KP                 111445 non-null  int64
#  47  DST                111445 non-null  int64
#  48  AE                 111445 non-null  int64
#  49  AP_INDEX           111445 non-null  int64
#  50  AL_INDEX           111445 non-null  int64
#  51  AU_INDEX           111445 non-null  int64
#  52  PC_N_INDEX         111445 non-null  float64
#  53  Solar_Lyman_alpha  111445 non-null  float64
#  54  Proton_QI          111445 non-null  float64
# dtypes: float64(42), int64(13)
# memory usage: 47.6+ MB

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
target_column = 'KP'
correlations = df.corr()[target_column]
correlations = correlations
correlations
# Out:
# Epoch                0.004194
# Rot#                 0.062243
# IMF                  0.042180
# PLS                  0.021568
# IMF_PTS              0.041789
# PLS_PTS              0.016591
# ABS_B                0.051633
# F                    0.049321
# THETA_AV            -0.014992
# PHI_AV               0.013353
# BX_GSE               0.040573
# BY_GSE               0.041355
# BZ_GSE               0.035032
# BY_GSM               0.040358
# BZ_GSM               0.032257
# SIGMA-ABS_B          0.041846
# SIGMA-B              0.046820
# SIGMA-Bx             0.043312
# SIGMA-By             0.044156
# SIGMA-Bz             0.044736
# T                    0.064653
# N                    0.020167
# V                    0.092283
# PHI-V                0.025216
# THETA-V              0.019994
# Ratio                0.013783
# Pressure             0.080838
# SIGMA-T              0.021087
# SIGMA-N              0.016369
# SIGMA-V              0.022125
# SIGMA-PHI-V          0.022114
# SIGMA-THETA-V        0.022605
# SIGMA-ratio          0.012057
# E                    0.042108
# Beta                 0.030583
# Mach_num             0.029361
# Mgs_mach_num         0.031789
# PR-FLX_1                  NaN
# PR-FLX_2                  NaN
# PR-FLX_4                  NaN
# PR-FLX_10           -0.001434
# PR-FLX_30           -0.001479
# PR-FLX_60           -0.001486
# MFLX                -0.001489
# R                    0.089859
# F10_INDEX            0.092312
# KP                   1.000000
# DST                 -0.552756
# AE                  -0.028938
# AP_INDEX             0.662843
# AL_INDEX            -0.050443
# AU_INDEX            -0.048464
# PC_N_INDEX           0.103370
# Solar_Lyman_alpha    0.059867
# Proton_QI            0.038696
# Name: KP, dtype: float64

# %%
drop_columns = ['Epoch','IMF', 'PLS', 'IMF_PTS', 'PLS_PTS','F',
       'THETA_AV', 'PHI_AV', 'BX_GSE', 'BY_GSE', 'BZ_GSE', 'BY_GSM', 'BZ_GSM',
       'SIGMA-ABS_B', 'SIGMA-B', 'SIGMA-Bx', 'SIGMA-By', 'SIGMA-Bz','N','PHI-V', 'THETA-V', 'Ratio','SIGMA-T', 'SIGMA-N',
       'SIGMA-V', 'SIGMA-PHI-V', 'SIGMA-THETA-V', 'SIGMA-ratio', 'E', 'Beta',
       'Mach_num', 'Mgs_mach_num', 'PR-FLX_1', 'PR-FLX_2', 'PR-FLX_4',
       'PR-FLX_10', 'PR-FLX_30', 'PR-FLX_60', 'MFLX','AE','AU_INDEX','Proton_QI']

df.drop(drop_columns, axis=1, inplace=True)

# %%
df.head(1)
# Out:
#                      Rot#  ABS_B        T      V  Pressure   R  F10_INDEX  KP  \
# Datetime
# 2011-01-01 00:00:00  2421    4.6  39168.0  326.0      0.83  48      999.9  13
#
#                      DST  AP_INDEX  AL_INDEX  PC_N_INDEX  Solar_Lyman_alpha
# Datetime
# 2011-01-01 00:00:00  -11         5       -12         0.2           0.006706

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Rot#', 'ABS_B', 'T', 'V', 'Pressure', 'R', 'F10_INDEX', 'KP', 'DST',
#        'AP_INDEX', 'AL_INDEX', 'PC_N_INDEX', 'Solar_Lyman_alpha'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Rot#                   173
# ABS_B                  299
# T                    80715
# V                      567
# Pressure              1259
# R                      209
# F10_INDEX             1134
# KP                      27
# DST                    235
# AP_INDEX                31
# AL_INDEX               962
# PC_N_INDEX             160
# Solar_Lyman_alpha     2314
# dtype: int64

# %%
df.max().round(2)
# Out:
# Rot#                    9999.00
# ABS_B                    999.90
# T                    9999999.00
# V                       9999.00
# Pressure                  99.99
# R                        999.00
# F10_INDEX                999.90
# KP                        99.00
# DST                       77.00
# AP_INDEX                 999.00
# AL_INDEX               99999.00
# PC_N_INDEX               999.90
# Solar_Lyman_alpha          1.00
# dtype: float64

# %%
df.min()
# Out:
# Rot#                 2421.000000
# ABS_B                   0.500000
# T                    3299.000000
# V                     240.000000
# Pressure                0.040000
# R                       0.000000
# F10_INDEX              63.400000
# KP                      0.000000
# DST                  -234.000000
# AP_INDEX                0.000000
# AL_INDEX            -1611.000000
# PC_N_INDEX             -5.900000
# Solar_Lyman_alpha       0.005839
# dtype: float64

# %%
x = df.drop(columns=['KP'])
y = df['KP']

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.3, random_state=0)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=0)

# %%
model = Sequential()

model.add(Dense(64, input_shape = (12,), activation= 'relu'))
model.add(Dense(64, activation= 'relu', bias_regularizer= L2(0.001)))
model.add(Dense(1, activation= 'linear'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 64)                832
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 5,057
# Trainable params: 5,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="mean_squared_error",
              optimizer=Adam(learning_rate=0.0001),
              metrics=[MeanAbsoluteError()])

# %%
history = model.fit(x_train, y_train, epochs=70, batch_size=256,validation_data=(x_val, y_val))
# Out:
# Epoch 1/70
# 305/305 [==============================] - 2s 5ms/step - loss: 393.2553 - mean_absolute_error: 15.5777 - val_loss: 334.7219 - val_mean_absolute_error: 14.0825
# Epoch 2/70
# 305/305 [==============================] - 1s 4ms/step - loss: 272.2342 - mean_absolute_error: 12.5491 - val_loss: 196.8734 - val_mean_absolute_error: 10.6495
# Epoch 3/70
# 305/305 [==============================] - 1s 4ms/step - loss: 149.0174 - mean_absolute_error: 9.3782 - val_loss: 106.7981 - val_mean_absolute_error: 8.2754
# Epoch 4/70
# 305/305 [==============================] - 1s 4ms/step - loss: 96.6427 - mean_absolute_error: 7.8315 - val_loss: 84.3909 - val_mean_absolute_error: 7.4482
# Epoch 5/70
# 305/305 [==============================] - 1s 5ms/step - loss: 81.9807 - mean_absolute_error: 7.2536 - val_loss: 75.4576 - val_mean_absolute_error: 7.0161
# Epoch 6/70
# 305/305 [==============================] - 1s 5ms/step - loss: 73.1669 - mean_absolute_error: 6.8494 - val_loss: 68.0832 - val_mean_absolute_error: 6.6502
# Epoch 7/70
# 305/305 [==============================] - 1s 5ms/step - loss: 65.4691 - mean_absolute_error: 6.4821 - val_loss: 60.9533 - val_mean_absolute_error: 6.2900
# Epoch 8/70
# 305/305 [==============================] - 1s 4ms/step - loss: 58.0302 - mean_absolute_error: 6.1075 - val_loss: 53.9345 - val_mean_absolute_error: 5.9029
# Epoch 9/70
# 305/305 [==============================] - 1s 4ms/step - loss: 50.7027 - mean_absolute_error: 5.6894 - val_loss: 46.7930 - val_mean_absolute_error: 5.4617
# Epoch 10/70
# 305/305 [==============================] - 1s 4ms/step - loss: 43.3434 - mean_absolute_error: 5.2208 - val_loss: 39.5083 - val_mean_absolute_error: 4.9628
# Epoch 11/70
# 305/305 [==============================] - 1s 4ms/step - loss: 36.1894 - mean_absolute_error: 4.7159 - val_loss: 32.6712 - val_mean_absolute_error: 4.4500
# Epoch 12/70
# 305/305 [==============================] - 1s 4ms/step - loss: 29.4643 - mean_absolute_error: 4.1733 - val_loss: 26.3126 - val_mean_absolute_error: 3.9334
# Epoch 13/70
# 305/305 [==============================] - 1s 4ms/step - loss: 23.4835 - mean_absolute_error: 3.6368 - val_loss: 20.7943 - val_mean_absolute_error: 3.4209
# Epoch 14/70
# 305/305 [==============================] - 1s 4ms/step - loss: 18.3972 - mean_absolute_error: 3.1244 - val_loss: 16.0847 - val_mean_absolute_error: 2.8794
# Epoch 15/70
# 305/305 [==============================] - 1s 4ms/step - loss: 14.2177 - mean_absolute_error: 2.6316 - val_loss: 12.4293 - val_mean_absolute_error: 2.4089
# Epoch 16/70
# 305/305 [==============================] - 1s 3ms/step - loss: 11.0736 - mean_absolute_error: 2.2174 - val_loss: 9.7372 - val_mean_absolute_error: 2.0569
# Epoch 17/70
# 305/305 [==============================] - 1s 4ms/step - loss: 8.7799 - mean_absolute_error: 1.9001 - val_loss: 7.7993 - val_mean_absolute_error: 1.7762
# Epoch 18/70
# 305/305 [==============================] - 1s 4ms/step - loss: 7.1105 - mean_absolute_error: 1.6674 - val_loss: 6.4385 - val_mean_absolute_error: 1.5717
# Epoch 19/70
# 305/305 [==============================] - 1s 4ms/step - loss: 5.9443 - mean_absolute_error: 1.5000 - val_loss: 5.4621 - val_mean_absolute_error: 1.4417
# Epoch 20/70
# 305/305 [==============================] - 1s 3ms/step - loss: 5.0955 - mean_absolute_error: 1.3895 - val_loss: 4.7597 - val_mean_absolute_error: 1.3499
# Epoch 21/70
# 305/305 [==============================] - 1s 3ms/step - loss: 4.4672 - mean_absolute_error: 1.3020 - val_loss: 4.2381 - val_mean_absolute_error: 1.2690
# Epoch 22/70
# 305/305 [==============================] - 1s 4ms/step - loss: 3.9814 - mean_absolute_error: 1.2264 - val_loss: 3.8224 - val_mean_absolute_error: 1.2032
# Epoch 23/70
# 305/305 [==============================] - 1s 3ms/step - loss: 3.5943 - mean_absolute_error: 1.1656 - val_loss: 3.4958 - val_mean_absolute_error: 1.1376
# Epoch 24/70
# 305/305 [==============================] - 1s 3ms/step - loss: 3.2762 - mean_absolute_error: 1.1066 - val_loss: 3.2304 - val_mean_absolute_error: 1.0895
# Epoch 25/70
# 305/305 [==============================] - 1s 3ms/step - loss: 3.0089 - mean_absolute_error: 1.0585 - val_loss: 2.9905 - val_mean_absolute_error: 1.0371
# Epoch 26/70
# 305/305 [==============================] - 1s 3ms/step - loss: 2.7811 - mean_absolute_error: 1.0134 - val_loss: 2.8089 - val_mean_absolute_error: 0.9952
# Epoch 27/70
# 305/305 [==============================] - 1s 4ms/step - loss: 2.5851 - mean_absolute_error: 0.9773 - val_loss: 2.6182 - val_mean_absolute_error: 0.9635
# Epoch 28/70
# 305/305 [==============================] - 1s 4ms/step - loss: 2.4075 - mean_absolute_error: 0.9373 - val_loss: 2.4601 - val_mean_absolute_error: 0.9359
# Epoch 29/70
# 305/305 [==============================] - 1s 4ms/step - loss: 2.2563 - mean_absolute_error: 0.9067 - val_loss: 2.3223 - val_mean_absolute_error: 0.8873
# Epoch 30/70
# 305/305 [==============================] - 1s 4ms/step - loss: 2.1166 - mean_absolute_error: 0.8748 - val_loss: 2.1871 - val_mean_absolute_error: 0.8657
# Epoch 31/70
# 305/305 [==============================] - 1s 3ms/step - loss: 1.9910 - mean_absolute_error: 0.8480 - val_loss: 2.0822 - val_mean_absolute_error: 0.8364
# Epoch 32/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.8861 - mean_absolute_error: 0.8218 - val_loss: 1.9922 - val_mean_absolute_error: 0.8083
# Epoch 33/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.7832 - mean_absolute_error: 0.7998 - val_loss: 1.9088 - val_mean_absolute_error: 0.8069
# Epoch 34/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.7030 - mean_absolute_error: 0.7809 - val_loss: 1.8169 - val_mean_absolute_error: 0.7787
# Epoch 35/70
# 305/305 [==============================] - 2s 5ms/step - loss: 1.6255 - mean_absolute_error: 0.7609 - val_loss: 1.7536 - val_mean_absolute_error: 0.7725
# Epoch 36/70
# 305/305 [==============================] - 2s 5ms/step - loss: 1.5558 - mean_absolute_error: 0.7432 - val_loss: 1.6807 - val_mean_absolute_error: 0.7426
# Epoch 37/70
# 305/305 [==============================] - 1s 5ms/step - loss: 1.4963 - mean_absolute_error: 0.7259 - val_loss: 1.6174 - val_mean_absolute_error: 0.7231
# Epoch 38/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.4381 - mean_absolute_error: 0.7100 - val_loss: 1.5652 - val_mean_absolute_error: 0.6991
# Epoch 39/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.3888 - mean_absolute_error: 0.6937 - val_loss: 1.5119 - val_mean_absolute_error: 0.6841
# Epoch 40/70
# 305/305 [==============================] - 1s 3ms/step - loss: 1.3421 - mean_absolute_error: 0.6790 - val_loss: 1.4737 - val_mean_absolute_error: 0.6787
# Epoch 41/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.2945 - mean_absolute_error: 0.6648 - val_loss: 1.4269 - val_mean_absolute_error: 0.6552
# Epoch 42/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.2411 - mean_absolute_error: 0.6461 - val_loss: 1.3680 - val_mean_absolute_error: 0.6374
# Epoch 43/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.1891 - mean_absolute_error: 0.6276 - val_loss: 1.3261 - val_mean_absolute_error: 0.6212
# Epoch 44/70
# 305/305 [==============================] - 1s 5ms/step - loss: 1.1469 - mean_absolute_error: 0.6130 - val_loss: 1.2809 - val_mean_absolute_error: 0.6046
# Epoch 45/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.1047 - mean_absolute_error: 0.5980 - val_loss: 1.2382 - val_mean_absolute_error: 0.5932
# Epoch 46/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.0689 - mean_absolute_error: 0.5864 - val_loss: 1.2069 - val_mean_absolute_error: 0.5825
# Epoch 47/70
# 305/305 [==============================] - 1s 3ms/step - loss: 1.0355 - mean_absolute_error: 0.5726 - val_loss: 1.1729 - val_mean_absolute_error: 0.5788
# Epoch 48/70
# 305/305 [==============================] - 1s 4ms/step - loss: 1.0027 - mean_absolute_error: 0.5640 - val_loss: 1.1453 - val_mean_absolute_error: 0.5600
# Epoch 49/70
# 305/305 [==============================] - 1s 4ms/step - loss: 0.9770 - mean_absolute_error: 0.5538 - val_loss: 1.1256 - val_mean_absolute_error: 0.5569
# Epoch 50/70
# 305/305 [==============================] - 1s 4ms/step - loss: 0.9498 - mean_absolute_error: 0.5416 - val_loss: 1.0909 - val_mean_absolute_error: 0.5442
# Epoch 51/70
# 305/305 [==============================] - 1s 5ms/step - loss: 0.9253 - mean_absolute_error: 0.5340 - val_loss: 1.0668 - val_mean_absolute_error: 0.5330
# Epoch 52/70
# 305/305 [==============================] - 1s 4ms/step - loss: 0.8999 - mean_absolute_error: 0.5258 - val_loss: 1.0432 - val_mean_absolute_error: 0.5252
# Epoch 53/70
# 305/305 [==============================] - 1s 5ms/step - loss: 0.8761 - mean_absolute_error: 0.5150 - val_loss: 1.0178 - val_mean_absolute_error: 0.5150
# Epoch 54/70
# 305/305 [==============================] - 2s 6ms/step - loss: 0.8545 - mean_absolute_error: 0.5062 - val_loss: 0.9985 - val_mean_absolute_error: 0.5028
# Epoch 55/70
# 305/305 [==============================] - 1s 5ms/step - loss: 0.8353 - mean_absolute_error: 0.4979 - val_loss: 0.9768 - val_mean_absolute_error: 0.4959
# Epoch 56/70
# 305/305 [==============================] - 2s 6ms/step - loss: 0.8133 - mean_absolute_error: 0.4911 - val_loss: 0.9591 - val_mean_absolute_error: 0.4926
# Epoch 57/70
# 305/305 [==============================] - 2s 6ms/step - loss: 0.7926 - mean_absolute_error: 0.4809 - val_loss: 0.9557 - val_mean_absolute_error: 0.4868
# Epoch 58/70
# 305/305 [==============================] - 1s 4ms/step - loss: 0.7752 - mean_absolute_error: 0.4752 - val_loss: 0.9216 - val_mean_absolute_error: 0.4742
# Epoch 59/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.7558 - mean_absolute_error: 0.4659 - val_loss: 0.9112 - val_mean_absolute_error: 0.4661
# Epoch 60/70
# 305/305 [==============================] - 1s 4ms/step - loss: 0.7378 - mean_absolute_error: 0.4586 - val_loss: 0.8950 - val_mean_absolute_error: 0.4649
# Epoch 61/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.7256 - mean_absolute_error: 0.4544 - val_loss: 0.8773 - val_mean_absolute_error: 0.4499
# Epoch 62/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.7070 - mean_absolute_error: 0.4446 - val_loss: 0.8570 - val_mean_absolute_error: 0.4427
# Epoch 63/70
# 305/305 [==============================] - 2s 5ms/step - loss: 0.6937 - mean_absolute_error: 0.4383 - val_loss: 0.8507 - val_mean_absolute_error: 0.4432
# Epoch 64/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.6791 - mean_absolute_error: 0.4326 - val_loss: 0.8309 - val_mean_absolute_error: 0.4328
# Epoch 65/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.6669 - mean_absolute_error: 0.4259 - val_loss: 0.8119 - val_mean_absolute_error: 0.4242
# Epoch 66/70
# 305/305 [==============================] - 1s 4ms/step - loss: 0.6541 - mean_absolute_error: 0.4182 - val_loss: 0.8019 - val_mean_absolute_error: 0.4239
# Epoch 67/70
# 305/305 [==============================] - 1s 4ms/step - loss: 0.6390 - mean_absolute_error: 0.4132 - val_loss: 0.8041 - val_mean_absolute_error: 0.4173
# Epoch 68/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.6294 - mean_absolute_error: 0.4075 - val_loss: 0.7783 - val_mean_absolute_error: 0.4059
# Epoch 69/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.6148 - mean_absolute_error: 0.4003 - val_loss: 0.7728 - val_mean_absolute_error: 0.4131
# Epoch 70/70
# 305/305 [==============================] - 1s 3ms/step - loss: 0.6034 - mean_absolute_error: 0.3949 - val_loss: 0.7601 - val_mean_absolute_error: 0.3982

# %%
val_loss = history.history['val_loss']

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
predictions = model.predict(x_test)
# Out:
# 523/523 [==============================] - 1s 1ms/step

# %%
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.4f}")
# Out:
# RMSE: 0.7544

# %%
r2 = r2_score(y_test, predictions)
print(f"R2 Score: {r2:.4f}")
# Out:
# R2 Score: 0.9963

# %%
# model.save('solar_wind.h')

# %%
x = range(len(predictions))

plt.plot(x, y_test, label='Actual', color='blue')

plt.plot(x, predictions, label='Predicted', color='red')

plt.xlabel('Data Point Index')
plt.ylabel('Value')
plt.legend()

plt.show()
